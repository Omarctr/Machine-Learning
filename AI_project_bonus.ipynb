# %% [markdown]
# <a href="https://colab.research.google.com/github/Omarctr/Machine-Learning/blob/main/AI_project_bonus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #** classification using naive bayes**

# %% [markdown]
# **we will use spam or ham dataset**

# %%
import pandas as pd
# Out:
# 'أهلا بكم في اللغة العربية'
